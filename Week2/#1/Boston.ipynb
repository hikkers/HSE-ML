# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_boston
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import scale

X, y = load_boston(return_X_y=True)
X.shape
# Out:
# (506, 13)

# %%
sc = scale(X)
sc
# Out:
# array([[-0.41978194,  0.28482986, -1.2879095 , ..., -1.45900038,
#          0.44105193, -1.0755623 ],
#        [-0.41733926, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.44105193, -0.49243937],
#        [-0.41734159, -0.48772236, -0.59338101, ..., -0.30309415,
#          0.39642699, -1.2087274 ],
#        ...,
#        [-0.41344658, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.98304761],
#        [-0.40776407, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.4032249 , -0.86530163],
#        [-0.41500016, -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.66905833]])

# %%
samp = np.linspace(1, 10, num=200)
samp
# Out:
# array([ 1.        ,  1.04522613,  1.09045226,  1.13567839,  1.18090452,
#         1.22613065,  1.27135678,  1.31658291,  1.36180905,  1.40703518,
#         1.45226131,  1.49748744,  1.54271357,  1.5879397 ,  1.63316583,
#         1.67839196,  1.72361809,  1.76884422,  1.81407035,  1.85929648,
#         1.90452261,  1.94974874,  1.99497487,  2.04020101,  2.08542714,
#         2.13065327,  2.1758794 ,  2.22110553,  2.26633166,  2.31155779,
#         2.35678392,  2.40201005,  2.44723618,  2.49246231,  2.53768844,
#         2.58291457,  2.6281407 ,  2.67336683,  2.71859296,  2.7638191 ,
#         2.80904523,  2.85427136,  2.89949749,  2.94472362,  2.98994975,
#         3.03517588,  3.08040201,  3.12562814,  3.17085427,  3.2160804 ,
#         3.26130653,  3.30653266,  3.35175879,  3.39698492,  3.44221106,
#         3.48743719,  3.53266332,  3.57788945,  3.62311558,  3.66834171,
#         3.71356784,  3.75879397,  3.8040201 ,  3.84924623,  3.89447236,
# ...

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
p_best = {}
acc = 0


for i in samp:
    knn = KNeighborsRegressor(n_neighbors=5, weights='distance', p=i)
    
    qual = cross_val_score(knn, X, y, cv=kf, scoring='neg_mean_squared_error')
    mean_qual = np.mean(qual)
    p_best[i] = mean_qual
# Out:
# {1.0: -29.7872280754304, 1.0452261306532664: -30.206823991751406, 1.0904522613065326: -30.411844062975423, 1.135678391959799: -30.97042179593103, 1.1809045226130652: -31.203063422624012, 1.2261306532663316: -31.26017880077607, 1.271356783919598: -31.91025494789222, 1.3165829145728645: -32.29378025232052, 1.3618090452261307: -32.88732359621541, 1.4070351758793969: -33.71911507634873, 1.4522613065326633: -34.29250061396575, 1.4974874371859297: -34.40110912135927, 1.542713567839196: -34.46284917290634, 1.5879396984924623: -34.40627605071838, 1.6331658291457287: -34.77332594213874, 1.678391959798995: -34.8600566222828, 1.7236180904522613: -34.987619571766245, 1.7688442211055277: -35.33888010213603, 1.814070351758794: -35.78180003754431, 1.8592964824120604: -35.8101337039665, 1.9045226130653266: -35.97983006882628, 1.949748743718593: -36.321047894749746, 1.9949748743718594: -36.37887869739649, 2.040201005025126: -36.577809535745175, 2.085427135678392: -37.08789802649521, 2.130653266331658
# ...

# %%
max_value = max(p_best.values())
max_key = [key for key, value in p_best.items() if value == max_value]

print(max_key, max_value)
# Out:
# [1.0] -29.7872280754304
