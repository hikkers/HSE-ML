# %%
import pandas as pd
import numpy as np

train = pd.read_csv('close_prices.csv', index_col='date')
train.head()
# Out:
#                   AXP          BA        CAT       CSCO         CVX  \
# date
# 2013-09-23  76.440002  117.510002  85.029999  24.270000  125.519997
# 2013-09-24  76.070000  119.000000  85.110001  24.139999  124.489998
# 2013-09-25  75.989998  118.510002  84.500000  24.430000  124.070000
# 2013-09-26  76.320000  119.379997  84.199997  23.770000  123.489998
# 2013-09-27  75.889999  118.739998  83.800003  23.330000  122.639999
#
#                    DD        DIS         GE          GS         HD  ...  \
# date                                                                ...
# 2013-09-23  59.409999  64.750000  24.280001  165.250000  75.910004  ...
# 2013-09-24  59.319997  64.320000  24.320000  162.970001  76.040001  ...
# 2013-09-25  59.319997  64.449997  24.230000  162.309998  75.519997  ...
# 2013-09-26  59.509996  65.239998  24.250000  162.289993  76.070000  ...
# 2013-09-27  59.009995  65.190002  24.049999  159.850006  75.959999  ...
#
# ...

# %%
from datetime import datetime

train['date'] = train['date'].apply(lambda x: x.replace('-',''))
train
# Out:
#          date        AXP          BA        CAT       CSCO         CVX  \
# 0    20130923  76.440002  117.510002  85.029999  24.270000  125.519997
# 1    20130924  76.070000  119.000000  85.110001  24.139999  124.489998
# 2    20130925  75.989998  118.510002  84.500000  24.430000  124.070000
# 3    20130926  76.320000  119.379997  84.199997  23.770000  123.489998
# 4    20130927  75.889999  118.739998  83.800003  23.330000  122.639999
# ..        ...        ...         ...        ...        ...         ...
# 369  20150312  81.559998  152.039993  80.190002  28.240000  102.419998
# 370  20150313  80.599998  151.570007  79.230003  27.940001  101.620003
# 371  20150316  81.500000  153.669998  79.970001  28.299999  103.129997
# 372  20150317  81.059998  154.509995  78.449997  28.150000  103.169998
# 373  20150318  81.860001  155.729996  81.330002  28.150000  106.699997
#
#             DD         DIS         GE          GS  ...        PFE         PG  \
# ...

# %%
from sklearn.decomposition import PCA

pca_mdl = PCA(n_components=10)
pca_mdl.fit(train)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
pca_mdl.explained_variance_ratio_[0:4].sum()
# Out:
# 0.9277429537836405

# %%
pca_mdl.transform(train)
# Out:
# array([[-50.90240358,  17.63167724,   7.7360209 , ...,   3.55657041,
#          -5.82197358,  -1.72604005],
#        [-52.84690919,  19.14690749,   7.27254551, ...,   3.43259929,
#          -5.63318106,  -2.0122316 ],
#        [-54.61443917,  19.92735811,   8.10995831, ...,   4.17520282,
#          -5.38828678,  -2.75269933],
#        ...,
#        [ 83.79819948,  16.95241334,  -8.25265611, ...,   2.92390381,
#          -4.59543822,  -2.99033503],
#        [ 79.19578947,  19.14436008,  -6.93262976, ...,   3.40475421,
#          -3.66793327,  -3.57607629],
#        [ 82.96885933,  13.13513974,  -9.07644299, ...,   3.75100423,
#          -4.79172198,  -3.03918865]])

# %%
comp = pd.DataFrame(pca_mdl.transform(train)[:,0])
comp
# Out:
#              0
# 0   -50.902404
# 1   -52.846909
# 2   -54.614439
# 3   -52.600566
# 4   -52.370123
# ..         ...
# 369  81.290980
# 370  77.903534
# 371  83.798199
# 372  79.195789
# 373  82.968859
#
# [374 rows x 1 columns]

# %%
test = pd.read_csv('djia_index.csv', index_col='date')
test
# Out:
#                     ^DJI
# date
# 2013-09-23  15401.379883
# 2013-09-24  15334.589844
# 2013-09-25  15273.259766
# 2013-09-26  15328.299805
# 2013-09-27  15258.240234
# ...                  ...
# 2015-03-12  17895.220703
# 2015-03-13  17749.310547
# 2015-03-16  17977.419922
# 2015-03-17  17849.080078
# 2015-03-18  18076.189453
#
# [374 rows x 1 columns]

# %%
coef = np.corrcoef(comp.T, test.T)[1,0]
print("Corrcoef %0.2f" % coef)
# Out:
# Corrcoef 0.91

# %%
print(train.columns[ np.argmax( pca_mdl.components_[1])])
# Out:
# V
